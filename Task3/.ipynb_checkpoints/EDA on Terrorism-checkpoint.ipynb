# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # Reading the Dataset

# %%
terror=pd.read_csv(r'C:\Users\lenovo\Desktop\LGM_DataScience\LGM_DataScience\Task3\TerrorismData.csv',encoding="ISO-8859-1")

# %%
terror.columns.to_list()
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
# ...

# %%
terror.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
terror.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
terror.shape
# Out:
# (181691, 135)

# %%
terror.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
terror.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
for i in terror.columns:
    print(i,end=",")
# Out:
# eventid,iyear,imonth,iday,approxdate,extended,resolution,country,country_txt,region,region_txt,provstate,city,latitude,longitude,specificity,vicinity,location,summary,crit1,crit2,crit3,doubtterr,alternative,alternative_txt,multiple,success,suicide,attacktype1,attacktype1_txt,attacktype2,attacktype2_txt,attacktype3,attacktype3_txt,targtype1,targtype1_txt,targsubtype1,targsubtype1_txt,corp1,target1,natlty1,natlty1_txt,targtype2,targtype2_txt,targsubtype2,targsubtype2_txt,corp2,target2,natlty2,natlty2_txt,targtype3,targtype3_txt,targsubtype3,targsubtype3_txt,corp3,target3,natlty3,natlty3_txt,gname,gsubname,gname2,gsubname2,gname3,gsubname3,motive,guncertain1,guncertain2,guncertain3,individual,nperps,nperpcap,claimed,claimmode,claimmode_txt,claim2,claimmode2,claimmode2_txt,claim3,claimmode3,claimmode3_txt,compclaim,weaptype1,weaptype1_txt,weapsubtype1,weapsubtype1_txt,weaptype2,weaptype2_txt,weapsubtype2,weapsubtype2_txt,weaptype3,weaptype3_txt,weapsubtype3,weapsubtype3_txt,weaptype4,wea
# ...

# %% [markdown]
# # Renaming Columns

# %%
terror.rename(columns={'iyear':'Year','imonth':'Month','city':'City','iday':'Day','country_txt':'Country','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)
terror['Casualities'] = terror.Killed + terror.Wounded
terror=terror[['Year','Month','Day','Country','Region','City','latitude','longitude','AttackType','Killed','Wounded','Casualities','Target','Group','Target_type','Weapon_type']]

# %%
terror.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'City', 'latitude',
#        'longitude', 'AttackType', 'Killed', 'Wounded', 'Casualities', 'Target',
#        'Group', 'Target_type', 'Weapon_type'],
#       dtype='object')

# %%
terror['Casualities']=terror.Killed+terror.Wounded

# %%
terror.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 16 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   Region       181691 non-null  object
#  5   City         181257 non-null  object
#  6   latitude     177135 non-null  float64
#  7   longitude    177134 non-null  float64
#  8   AttackType   181691 non-null  object
#  9   Killed       171378 non-null  float64
#  10  Wounded      165380 non-null  float64
#  11  Casualities  164817 non-null  float64
#  12  Target       181055 non-null  object
#  13  Group        181691 non-null  object
#  14  Target_type  181691 non-null  object
#  15  Weapon_type  181691 non-null  object
# dtypes: float64(5), int64(3), object(8)
# memory usage: 22.2+ MB

# %%
terror.describe(include='all')
# Out:
#                  Year          Month            Day Country  \
# count   181691.000000  181691.000000  181691.000000  181691
# unique            NaN            NaN            NaN     205
# top               NaN            NaN            NaN    Iraq
# freq              NaN            NaN            NaN   24636
# mean      2002.638997       6.467277      15.505644     NaN
# std         13.259430       3.388303       8.814045     NaN
# min       1970.000000       0.000000       0.000000     NaN
# 25%       1991.000000       4.000000       8.000000     NaN
# 50%       2009.000000       6.000000      15.000000     NaN
# 75%       2014.000000       9.000000      23.000000     NaN
# max       2017.000000      12.000000      31.000000     NaN
#
#                             Region     City       latitude     longitude  \
# count                       181691   181257  177135.000000  1.771340e+05
# unique                          12    36674            NaN           NaN
# ...

# %%
terror.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#             City   latitude   longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded  Casualities                   Target  \
# ...

# %%
terror.tail()
# Out:
#         Year  Month  Day      Country                      Region  \
# 181686  2017     12   31      Somalia          Sub-Saharan Africa
# 181687  2017     12   31        Syria  Middle East & North Africa
# 181688  2017     12   31  Philippines              Southeast Asia
# 181689  2017     12   31        India                  South Asia
# 181690  2017     12   31  Philippines              Southeast Asia
#
#                  City   latitude   longitude                      AttackType  \
# 181686  Ceelka Geelow   2.359673   45.385034                   Armed Assault
# 181687         Jableh  35.407278   35.942679               Bombing/Explosion
# 181688       Kubentog   6.900742  124.437908  Facility/Infrastructure Attack
# 181689         Imphal  24.798346   93.940430               Bombing/Explosion
# 181690  Cotabato City   7.209594  124.241966               Bombing/Explosion
#
#         Killed  Wounded  Casualities            Target  \
# ...

# %%
terror.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# Region             0
# City             434
# latitude        4556
# longitude       4557
# AttackType         0
# Killed         10313
# Wounded        16311
# Casualities    16874
# Target           636
# Group              0
# Target_type        0
# Weapon_type        0
# dtype: int64

# %% [markdown]
# # Visualizing Data

# %% [markdown]
# ## 1.Year Wise Attacks

# %%
attacks=terror["Year"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"Year","Year":"Attacks"}).set_index("Year")

# %%
attacks.plot(kind="bar",color="cornflowerblue",figsize=(15,6),fontsize=13)
plt.title("Timeline of Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %% [markdown]
# ### a.Casualities each year

# %%
yc = terror[["Year","Casualities"]].groupby("Year").sum()
yc.head()
# Out:
#       Casualities
# Year
# 1970        367.0
# 1971        119.0
# 1972        602.0
# 1973        621.0
# 1974       1122.0

# %%
yc.plot(kind="bar",color="cornflowerblue",figsize=(15,10))
plt.title("Year wise Casualties",fontsize=13)
plt.xticks(fontsize=14)
plt.xlabel("Years",fontsize=13)
plt.ylabel("Number of casualties",fontsize=13)
plt.show()

# %% [markdown]
# ### b.Killed Each Year

# %%
yk = terror[["Year","Killed"]].groupby("Year").sum()
yk.head()
# Out:
#       Killed
# Year
# 1970   174.0
# 1971   173.0
# 1972   566.0
# 1973   370.0
# 1974   539.0

# %%
yk.plot(kind="bar",color="cornflowerblue",fontsize=13,figsize=(15,10))
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Deaths",fontsize=15)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# ### c.Wounded each year

# %%
yw = terror[["Year","Wounded"]].groupby("Year").sum()
yw.head()
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0

# %%
yw.plot(kind="bar",color="cornflowerblue",figsize=(15,6),fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Wounded",fontsize=15)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# ## 2.Region wise attack

# %% [markdown]
# ### a. Distribution of terrorist attacks over Regions from 1970-2017

# %%
reg = pd.crosstab(terror.Year,terror.Region)
reg.head()
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        8                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# Year
# 1970            2              12                          28            472
# 1971            1               5                          55            247
# 1972            0               1                          53             73
# 1973            2               1                          19             64
# 1974            4               2                          42            111
#
# ...

# %%
reg.plot(kind="area",stacked=False, alpha=1.0,figsize=(20,10))
plt.title("Region wise attacks",fontsize=20)
plt.xlabel("Years",fontsize=20)
plt.ylabel("Number of Attacks",fontsize=20)
plt.show()

# %% [markdown]
# ### b.Total terrorist attacks in each region from 1970-201

# %%
regt = reg.transpose()
regt["Total"]=regt.sum(axis=1)
ra = regt["Total"].sort_values(ascending=False)
ra
# Out:
# Region
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Total, dtype: int64

# %%
ra.plot(kind="bar",figsize=(15,6))
plt.title("Total Number of Attacks in each region from 1970-2017")
plt.xlabel("Region")
plt.ylabel("Number of Attacks")
plt.show()

# %% [markdown]
# ### c.Total Casualties (Killed + Wounded) in eaqch region

# %%
rc = terror[["Region","Casualities"]].groupby("Region").sum()
rc.head()
# Out:
#                              Casualities
# Region
# Australasia & Oceania              409.0
# Central America & Caribbean      34530.0
# Central Asia                      2969.0
# East Asia                        10003.0
# Eastern Europe                   18239.0

# %%
rc.sort_values(by="Casualities", ascending=True)
rc
# Out:
#                              Casualities
# Region
# Australasia & Oceania              409.0
# Central America & Caribbean      34530.0
# Central Asia                      2969.0
# East Asia                        10003.0
# Eastern Europe                   18239.0
# Middle East & North Africa      329807.0
# North America                    26398.0
# South America                    43562.0
# South Asia                      234366.0
# Southeast Asia                   40841.0
# Sub-Saharan Africa              108990.0
# Western Europe                   22778.0

# %%
rw = terror[["Region","Wounded"]].groupby("Region").sum().sort_values(by="Wounded",ascending=False)
rw
# Out:
#                               Wounded
# Region
# Middle East & North Africa   214308.0
# South Asia                   141360.0
# Sub-Saharan Africa            52857.0
# Southeast Asia                26259.0
# North America                 21531.0
# Western Europe                18332.0
# South America                 16704.0
# Eastern Europe                12045.0
# East Asia                      9213.0
# Central America & Caribbean    8991.0
# Central Asia                   2009.0
# Australasia & Oceania           260.0

# %%
rw.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.xlabel("Regions",fontsize=15)
plt.ylabel("Number of people Killed",fontsize=15)
plt.title("People killed in each region")
plt.show()

# %%
rc.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.xlabel("Regions",fontsize=15)
plt.ylabel("Number of Casualties",fontsize=15)
plt.title("Casualties in each region")
plt.show()

# %% [markdown]
# # 3.Country wise attack

# %% [markdown]
# # a.Number of attacks in each country

# %%
ct = terror["Country"].value_counts().head(10)
ct
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
ct.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Country wise attacks",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# ### b.Killed in each Country

# %%
cnk = terror[["Country","Killed"]].groupby("Country").sum().sort_values(by="Killed",ascending=False)
cnk.head()
# Out:
#               Killed
# Country
# Iraq         78589.0
# Afghanistan  39384.0
# Pakistan     23822.0
# Nigeria      22682.0
# India        19341.0

# %%
cnk[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("People killed in each country",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.ylabel("Number of Deaths",fontsize=13)
plt.show()

# %%
cnw = terror[["Country","Wounded"]].groupby("Country").sum().sort_values(by="Country",ascending=False)
cnw.head()
# Out:
#             Wounded
# Country
# Zimbabwe      222.0
# Zambia         62.0
# Zaire         211.0
# Yugoslavia    281.0
# Yemen        9328.0

# %%
cnw[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("People wounded in different countries",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.ylabel("Number of People wounded",fontsize=13)
plt.show()

# %% [markdown]
# # 4.City wise attacks

# %% [markdown]
# ### a.Number of attacks in each city

# %%
city = terror["City"].value_counts()[1:11]
city
# Out:
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Athens          1019
# Name: City, dtype: int64

# %%
city.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Country wise attacks",fontsize=13)
plt.xlabel("Cities",fontsize=13)
plt.ylabel("Number of attacks",fontsize=13)
plt.show()

# %% [markdown]
# ### b.Total casualties (Killed+Wounded) in each city

# %%
cc=terror[["City","Casualities"]].groupby("City").sum().sort_values(by="City",ascending=True).drop("Unknown")
cc.head(10)
# Out:
#                             Casualities
# City
# 62 miles South of Dushanbe          3.0
# A Coruna district                   6.0
# A'arbaniyeh                         3.0
# ANkara                              0.0
# Aab Kamra                          37.0
# Aabde                               4.0
# Aabdeh                              1.0
# Aabgarmak                           5.0
# Aachen                              2.0
# Aadaisse                            0.0

# %%
cc[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Casualties in different Cities",fontsize=13)
plt.xlabel("Cities",fontsize=13)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# # Most Affected Countries

# %%
most_terror = terror['Country'].value_counts()
pd.DataFrame(most_terror.head(5))
# Out:
#              Country
# Iraq           24636
# Pakistan       14368
# Afghanistan    12731
# India          11960
# Colombia        8306

# %% [markdown]
# # Most Affected Cities

# %%
pd.DataFrame(terror['City'].value_counts()[:5])
# Out:
#          City
# Unknown  9775
# Baghdad  7589
# Karachi  2652
# Lima     2359
# Mosul    2265

# %%
chart=sns.catplot(x='Weapon_type',y='Year',kind='box',height=5,aspect=3,data=terror,orient="v")
chart.set_xticklabels(rotation=45)
chart.set_yticklabels(rotation=45)

# %% [markdown]
# # Conclusion from the Exploratory Data Analysis of Terrorism dataset

# %% [markdown]
# ### 1.The country that has experienced the highest number of terrorist attacks is Iraq.
# ### 2.The city that has experienced the highest number of terrorist attacks is Baghdad.
# ### 3.The terrorist group with the highest number of claimed attacks is the Taliban.
# ### 4.In the list of countries affected by the highest number of terrorist attacks, India holds the fourth position.
# ### 5.The year 2014 recorded the highest number of terrorist attacks, with a total of 16,903 incidents.
# ### 6.Terror attacks have had the greatest impact on the Middle East and North Africa region.
# ### 7.The most commonly utilized type of attack is bombing or explosion.
# ### 8.The most used weapons are explosives.
